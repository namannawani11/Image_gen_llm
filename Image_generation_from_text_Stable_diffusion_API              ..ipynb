# %%
# !pip install diffusers
from diffusers import StableDiffusionPipeline
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 21.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # API BASED MODEL FROM STABLITY AI

# %%
api_key='######7gYjHnxT7MPM0wIS93aryMLrxpaBVhzYAolSz4Beb###'

# %%
import requests, base64
from IPython.display import Image, display

response = requests.post(
    "https://api.stability.ai/v1/generation/stable-diffusion-xl-1024-v1-0/text-to-image",
    headers={"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"},
    json={
        "text_prompts": [{"text": "Create a full image of a yellow Suzuki Jimny in a three-quarter view, showing all parts from front to side, equipped with chrome alloy wheels, set in a desert", "weight": 1}],
        "cfg_scale": 7, "clip_guidance_preset": "FAST_BLUE", "height": 1024, "width": 1024, "samples": 1, "steps": 30
    },
)

if response.status_code == 200:
    for image in response.json().get("artifacts", []):
        if image["finishReason"] == "SUCCESS":
            display(Image(data=base64.b64decode(image["base64"])))
else:
    print(f"Error: {response.status_code}, {response.text}")

# %%
import requests, base64
from IPython.display import Image, display

response = requests.post(
    "https://api.stability.ai/v1/generation/stable-diffusion-xl-1024-v1-0/text-to-image",
    headers={"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"},
    json={
        "text_prompts": [{"text": "Create a full image of a white Lamborghini in a three-quarter view, showing all parts from front to side, equipped with chrome alloy wheels, set in a river", "weight": 1}],
        "cfg_scale": 7, "clip_guidance_preset": "FAST_BLUE", "height": 1024, "width": 1024, "samples": 1, "steps": 30
    },
)

if response.status_code == 200:
    for image in response.json().get("artifacts", []):
        if image["finishReason"] == "SUCCESS":
            display(Image(data=base64.b64decode(image["base64"])))
else:
    print(f"Error: {response.status_code}, {response.text}")

# %%
import requests, base64
from IPython.display import Image, display

response = requests.post(
    "https://api.stability.ai/v1/generation/stable-diffusion-xl-1024-v1-0/text-to-image",
    headers={"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"},
    json={
        "text_prompts": [{"text": "Create a full image of a black harleydavdison in a three-quarter view, showing all parts from front to side, equipped with chrome alloy wheels, set in a mountains", "weight": 1}],
        "cfg_scale": 7, "clip_guidance_preset": "FAST_BLUE", "height": 1024, "width": 1024, "samples": 1, "steps": 30
    },
)

if response.status_code == 200:
    for image in response.json().get("artifacts", []):
        if image["finishReason"] == "SUCCESS":
            display(Image(data=base64.b64decode(image["base64"])))
else:
    print(f"Error: {response.status_code}, {response.text}")
